# %% [markdown]
# <a href="https://colab.research.google.com/github/harshithagoud3504/LGMVIP---DataScience/blob/main/image_to_pencilsketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/drive/MyDrive/leopard.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=843x1000 at 0x7FC1D1A43450>

# %%
img1= cv2.imread('/content/drive/MyDrive/leopard.png') 
blur_image = cv2.blur(img1,(4,4))
print("diminished dimensions",blur_image.shape) 
cv2_imshow(blur_image)
# Out:
# diminished dimensions (1000, 843, 3)
# <PIL.Image.Image image mode=RGB size=843x1000 at 0x7FC1D00E3E90>

# %%
img2 = cv2.imread('/content/drive/MyDrive/leopard1.png')
scale_percent = 60
width = int(img2.shape[1] * scale_percent / 100)
height = int(img2.shape[0] * scale_percent / 100)
dim = (width, height)
resized_blur_image = cv2.resize(img2,dim)
cv2_imshow(resized_blur_image)
# Out:
# <PIL.Image.Image image mode=RGB size=505x600 at 0x7FC1D00E3210>

# %%
image = cv2.imread('/content/drive/MyDrive/leopard2.png')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=505x600 at 0x7FC1D00E9DD0>

# %%
grayblur =cv2.blur(gray_image,(4,4))
cv2_imshow(grayblur)
# Out:
# <PIL.Image.Image image mode=L size=505x600 at 0x7FC1D1957E50>

# %%
pencil_sketch =cv2.divide(gray_image,grayblur,scale=220.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=505x600 at 0x7FC1D0133650>
